# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# For machine learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data= pd.read_csv("house_prices_sample.csv")
data
# Out:
#    Size  Bedrooms  Age   Price
# 0   850         2   10  200000
# 1   900         2    5  220000
# 2  1200         3   15  250000
# 3  1500         4   20  300000
# 4  1700         3   10  330000
# 5  2000         4    5  400000
# 6  1100         2    8  210000
# 7  1300         3   12  260000
# 8  1600         3    8  310000
# 9  1800         4    3  420000

# %%
model = LinearRegression()
model.fit(data.[['Size','Bedrooms','Age']],data.Price)
# Out:
#   Cell In[3], line 2
#     model.fit(data.[['Size','Bedrooms','Age']],data.Price)
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Assistant
# I'll refactor the selected code snippet, focusing on fixing the syntax error and improving readability:

# %%
# Fit the linear regression model with features and target
model = LinearRegression()
model.fit(
    X=data[['Size', 'Bedrooms', 'Age']],  # Features
    y=data['Price']                       # Target variable
)
# Out:
# LinearRegression()

# %% [markdown]
# The refactored code:
# 1. Fixes the syntax error (there was an incorrect dot after `data`)
# 2. Uses named parameters for clarity
# 3. Adds comments to explain what each parameter represents
# 4. Uses proper spacing for better readability
#
# This makes the code more maintainable and clearer about what's being used as features and what's being predicted.

# %% [markdown]
# # User
# whay this is not running it was runed befor after i closed and re run it not run

# %% [markdown]
# # Assistant
# I see the issue now. Let me analyze what might be happening with your code:
#
# The error is likely occurring because:
#
# 1. You might be missing the import for `LinearRegression`
# 2. The `data` DataFrame might not be defined or loaded in your current session
# 3. There was a syntax error in your original code with `data.` having an extra dot
#
# Here's a corrected version that should run properly:

# %%
# Import necessary libraries
from sklearn.linear_model import LinearRegression
import pandas as pd

# Make sure your data is loaded
# If you don't have data loaded yet, you need to load it first, for example:
# data = pd.read_csv('your_data_file.csv')

# Then fit the model
model = LinearRegression()
model.fit(
    X=data[['Size', 'Bedrooms', 'Age']],  # Features
    y=data['Price']                       # Target variable
)
# Out:
# LinearRegression()

# %% [markdown]
# The key issues to check:
# 1. Ensure you have the required libraries imported
# 2. Verify that your `data` DataFrame is properly loaded and contains the columns you're trying to access
# 3. Check that the column names match exactly (case-sensitive)
# 4. Make sure you're running the code in the correct order (data loading before model fitting)
#
# If you're reopening a notebook or script, you need to run all the prerequisite cells that define your variables and import your libraries before running this code.

# %%
model = LinearRegression()
model.fit(data.[['Size','Bedrooms','Age']],data.Price)
model.predict([[1260,6,28]])
# Out:
#   Cell In[8], line 2
#     model.fit(data.[['Size','Bedrooms','Age']],data.Price)
#                    ^
# SyntaxError: invalid syntax

# %%
model = LinearRegression()
model.fit(data.[['Size','Bedrooms','Age']],data.Price)
model.predict([[1260,6,28]])

# %%
model = LinearRegression()
model.fit(data[['Size','Bedrooms','Age']], data.Price)  # Removed the dot before square brackets
model.predict([[1260,6,28]])

# %%
model.predict([[100,1,1]])
